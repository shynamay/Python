# %% [markdown]
# <a href="https://colab.research.google.com/github/shynamay/Python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def Hobbies():
  print("Choose hobbies that you have in common with you") 
  print("Music, Anime, Novel Books")
  topic = input()
  if topic == "Music":
    Music()
  elif topic == "Anime":
    Anime()
  elif topic == "Novel Books":
    NovelBooks()
  else:
    print("Yey! You've matched with people who share your interests.")

print()

def Music():
  print("Choose which genre your interested in.")
  print("OPM, POP, Folk")
  subtopic = input()
  if subtopic == "POP":
    POP()
  elif subtopic == "OPM":
    OPM()
  elif subtopic == "Folk":
    Folk()
  else:
    print("Yehey! You've matched with people who loves music.")

print()

def POP():
  print("Here are you matched with")
  print("Luffy, Kazehaya, Newton")
  peepk = input()
  if peepk == "Kazehaya":
    Kazehaya()
  elif peepk == "Luffy":
    Luffy()
  elif peepk == "Newton":
    Newton() 
  else:
    print("Congratulations, you've got a date!")
  
print()

def OPM():
  print("Here are you matched with")
  print("Luffy, Kazehaya, Newton")
  peepk = input()
  if peepk == "Kazehaya":
    Kazehaya()
  elif peepk == "Luffy":
    Luffy()
  elif peepk == "Newton":
    Newton() 
  else:
    print("Congratulations, you've got a date!")

print()

def Folk():
  print("Here are you matched with")
  print("Luffy, Kazehaya, Newton")
  peepk = input()
  if peepk == "Kazehaya":
    Kazehaya()
  elif peepk == "Luffy":
    Luffy()
  elif peepk == "Newton":
    Newton() 
  else:
    print("Congratulations, you've got a date!")

print()

def Kazehaya():
  print("Kazehaya's Status/Bio")
  print("22 years old and POP Lover")
  print("Swipe Left/Right")
  swipea = input()
  if swipea == "Right":
    print("You matched with Kazehaya")

print()

def Luffy():
  print("Luffy's Status/Bio")
  print("19 years old and OPM Lover")
  print("Swipe Left/Right")
  swipea = input()
  if swipea == "Left":
    print("You matched with Kazehaya")

print()

def Newton():
  print("Newton's Status/Bio")
  print("26 years old and Folk Lover")
  print("Swipe Left/Right")
  swipea = input()
  if swipea == "Right":
    print("You matched with Kazehaya")

print()

def Anime():
  print("Choose what favorite animes you like.")
  print("One Piece, Bleach, Naruto")
  animes = input()
  if animes == "Bleach":
    Bleach()
  elif animes == "One Piece":
    OnePiece()
  elif animes == "Naruto":
    Naruto()
  else:
    print("Yey! You've matched with people who loves to watched Anime.")

print()

def Naruto():
  print("You have been paired with")
  print("Aizen, Zoro, Sasuke")
  peepks = input()
  if peepks == "Sasuke":
    Sasuke()
  elif peepks == "Aizen":
    Aizen()
  elif peepks == "Zoro":
    Zoro() 
  else:
    print("Congratulations, you've got a date!")
  
print()

def Bleach():
  print("You have been paired with")
  print("Aizen, Zoro, Sasuke")
  peepks = input()
  if peepks == "Sasuke":
    Sasuke()
  elif peepks == "Aizen":
    Aizen()
  elif peepks == "Zoro":
    Zoro() 
  else:
    print("Congratulations, you've got a date!")
  
print()

def OnePiece():
  print("You have been paired with")
  print("Aizen, Zoro, Sasuke")
  peepks = input()
  if peepks == "Sasuke":
    Sasuke()
  elif peepks == "Aizen":
    Aizen()
  elif peepks == "Zoro":
    Zoro() 
  else:
    print("Congratulations, you've got a date!")
  
print()

def Sasuke():
  print("Sasuke's Status/Bio")
  print("19 years old and Love Watching Naruto")
  print("Swipe Left/Right")
  swipeb = input()
  if swipeb == "Left":
    print("You matched with Sasuke")

print()

def Aizen():
  print("Aizen's Status/Bio")
  print("29 years old and Love watching Bleach")
  print("Swipe Left/Right")
  swipeb = input()
  if swipeb == "Right":
    print("You matched with Aizen")

print()

def Zoro():
  print("Zoro's Status/Bio")
  print("19 years old and Love watching One Piece")
  print("Swipe Left/Right")
  swipeb = input()
  if swipeb == "Left":
    print("You matched with Zoro")

print()

if __name__ == "__main__":
  while True:
    print("Welcome to the Dating Game!")
    print("We want to help lonely people like you")
    print("Let's start with your name: ")
    name = input()

      
    
    Hobbies()
    Music()
    Anime()
